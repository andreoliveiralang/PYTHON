# %%
# como criar arrays?

# %%
numeros = np.array([]) #cria um arranjo de N dimensões,
#dentro do parenteses vamos adicionar uma lista de números
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 numeros = np.array([]) #cria um arranjo de N dimensões.
#
# NameError: name 'np' is not defined
