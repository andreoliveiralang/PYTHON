# %% [markdown]
# # DataFrames
#
# DataFrames are the workhorse of pandas and are directly inspired by the R programming language. We can think of a DataFrame as a bunch of Series objects put together to share the same index. Let's use pandas to explore this topic!

# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
np.random.seed(101) #quantas funções random tem em numpy = 3 randInt,randN,rand

# %%
df = pd.DataFrame(data=randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split()) # pd = pandas.
#data= matriz 5 linhas 4 colunas.
#split= quebra no espaço ao invez de virgula.
#df= definimos o valor de df = DataFrame.

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df.pop('W')
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
df
# Out:
#           X         Y         Z
# A  0.628133  0.907969  0.503826
# B -0.319318 -0.848077  0.605965
# C  0.740122  0.528813 -0.589001
# D -0.758872 -0.933237  0.955057
# E  1.978757  2.605967  0.683509

# %%
df.pop('Z')
# Out:
# A    0.503826
# B    0.605965
# C   -0.589001
# D    0.955057
# E    0.683509
# Name: Z, dtype: float64

# %%
df
# Out:
#           X         Y
# A  0.628133  0.907969
# B -0.319318 -0.848077
# C  0.740122  0.528813
# D -0.758872 -0.933237
# E  1.978757  2.605967

# %%
df['NEW'] = df['X']+df['Y']
df
# Out:
#           X         Y       NEW
# A  0.628133  0.907969  1.536102
# B -0.319318 -0.848077 -1.167395
# C  0.740122  0.528813  1.268936
# D -0.758872 -0.933237 -1.692109
# E  1.978757  2.605967  4.584725

# %%
df.set_index(['X','Y'],inplace=True)
df
# Out:
#                           NEW
# X         Y
#  0.628133  0.907969  1.536102
# -0.319318 -0.848077 -1.167395
#  0.740122  0.528813  1.268936
# -0.758872 -0.933237 -1.692109
#  1.978757  2.605967  4.584725

# %%
tabela = df['NEW'].unstack('Y')
tabela
# Out:
# Y          -0.933237  -0.848077   0.528813   0.907969   2.605967
# X
# -0.758872  -1.692109        NaN        NaN        NaN        NaN
# -0.319318        NaN  -1.167395        NaN        NaN        NaN
#  0.628133        NaN        NaN        NaN   1.536102        NaN
#  0.740122        NaN        NaN   1.268936        NaN        NaN
#  1.978757        NaN        NaN        NaN        NaN   4.584725

# %% [markdown]
# ## Selection and Indexing
#
# Let's learn the various methods to grab data from a DataFrame

# %%
df['W']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\D29079\Documents\GitHub\PYTHON\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df[['W','Z']]

# %%
# Pass a list of column names
df[['W','Z']]

# %%
# SQL Syntax (NOT RECOMMENDED!)
df.W

# %% [markdown]
# DataFrame Columns are just Series

# %%
type(df['W'])

# %% [markdown]
# **Creating a new column:**

# %%
df['new'] = df['W'] + df['Y']

# %%
df

# %% [markdown]
# ** Removing Columns**

# %%
df.drop('W',axis=1)

# %%
df

# %%
# Not inplace unless specified!
df

# %%
df.drop('new',axis=1,inplace=True)

# %%
df

# %% [markdown]
# Can also drop rows this way:

# %%
df.drop('E',axis=0)

# %%
df

# %%
df.drop('E')

# %%
df

# %%
df.iloc[3][2]

# %% [markdown]
# ** Selecting Rows**

# %%
df.loc['A']

# %% [markdown]
# Or select based off of position instead of label

# %%
df.iloc[0]

# %%
df.iloc[2][1]

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df.loc['B','Y']

# %%
df.loc[['A','B'],['W','Y']]

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df

# %%
df>0

# %%
df[df>0]

# %%
df[df['W']>0]

# %%
df

# %%
df[df['W']>0]['Y']

# %%
df[df['W']>0][['Y','X']]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df[(df['W']>0) & (df['Y'] > 1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df[(df['W']>0) & (df['Y'] > 1)]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
# Reset to default 0,1...n index
df.reset_index()

# %%
newdata = 'CA NY WY OR CO'.split()

# %%
newdata

# %%
df['States'] = newdata

# %%
df

# %%
df.set_index('States')

# %%
df

# %%
df.set_index('States',inplace=True)

# %%
df

# %% [markdown]
# ## Multi-Index and Index Hierarchy
#
# Let us go over how to work with Multi-Index, first we'll create a quick example of what a Multi-Indexed DataFrame would look like:

# %%
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2'] # outside- o mais externo

inside = [1,2,3,4,5,6]

hier_index = list(zip(outside,inside))

hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 4),
#             ('G2', 5),
#             ('G2', 6)],
#            )

# %%
df1 = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])

# %%
df1
# Out:
#              A         B
# G1 1  0.302665  1.693723
#    2 -1.706086 -1.159119
#    3 -0.134841  0.390528
# G2 4  0.166905  0.184502
#    5  0.807706  0.072960
#    6  0.638787  0.329646

# %% [markdown]
# Now let's show how to index this! For index hierarchy we use df.loc[], if this was on the columns axis, you would just use normal bracket notation df[]. Calling one level of the index returns the sub-dataframe:

# %%
df1.loc['G1'] #localiza especificamente oque esta definido no index
# Out:
#           A         B
# 1  0.302665  1.693723
# 2 -1.706086 -1.159119
# 3 -0.134841  0.390528

# %%
df1.loc['G1'].loc[1]
# Out:
# A    0.302665
# B    1.693723
# Name: 1, dtype: float64

# %%
df1.index.names
# Out:
# FrozenList([None, None])

# %%
df1.index.names = ['Group','Numbers']

# %%
df1
# Out:
#                       A         B
# Group Numbers
# G1    1        0.302665  1.693723
#       2       -1.706086 -1.159119
#       3       -0.134841  0.390528
# G2    4        0.166905  0.184502
#       5        0.807706  0.072960
#       6        0.638787  0.329646

# %%
df1
# Out:
#                       A         B
# Group Numbers
# G1    1        0.302665  1.693723
#       2       -1.706086 -1.159119
#       3       -0.134841  0.390528
# G2    4        0.166905  0.184502
#       5        0.807706  0.072960
#       6        0.638787  0.329646

# %%
df1.loc['G1']
# Out:
#                 A         B
# Numbers
# 1        0.302665  1.693723
# 2       -1.706086 -1.159119
# 3       -0.134841  0.390528

# %%
df1.xs('G1') #mais atual
# Out:
#                 A         B
# Numbers
# 1        0.302665  1.693723
# 2       -1.706086 -1.159119
# 3       -0.134841  0.390528

# %%
df1.xs(('G1',1))
# Out:
# A    0.302665
# B    1.693723
# Name: (G1, 1), dtype: float64

# %%
df1
# Out:
#                       A         B
# Group Numbers
# G1    1        0.302665  1.693723
#       2       -1.706086 -1.159119
#       3       -0.134841  0.390528
# G2    4        0.166905  0.184502
#       5        0.807706  0.072960
#       6        0.638787  0.329646

# %%
df1.xs(5,level='Numbers')
# Out:
#               A        B
# Group
# G2     0.807706  0.07296
